# %% [markdown]
# I will use the opaque defects and our cam output as csv files to practice table and chart creation for reports.

# %%
#I still have trouble remembering all of the shit to import
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
#I sometimes can remember how to open csvs with pandas
#Here I use indexing to remove all but the category I want to investigate.
#I then assign to my variable to make it permanent.
opaque_df = pd.read_csv('NumpyCsvTraining.csv', sep=',')
#dframe[dframe['C']>8]
opaque_df = opaque_df[opaque_df['DEFECT CATEGORY']=='SHADE / MATERIAL INCORRECT or CHANGED']
opaque_df.head()
# Out:
#               Timestamp CAM OPERATOR BADGE#  \
# 52    3/5/2020 14:04:24              DROMIE
# 53    3/5/2020 14:14:03              DROMIE
# 60    3/5/2020 17:20:30              DROMIE
# 109  3/12/2020 17:49:41                DLEE
# 234   3/23/2020 8:43:09           TSCHAFFER
#
#                                      SCAN CASE NUMBER  \
# 52                                   ROLO101520008157
# 53                                   SARA101520008275
# 60   ROLO101520008240ROLO101520008206ROLO101520008160
# 109                                  ROLO101520009638
# 234                                  SARA101520010560
#
#                            DEFECT CATEGORY               DEFECT DESCRIPTION  \
# 52   SHADE / MATERIAL INCORRECT or CHANGED            MILLED TOO LIGHT (A1)
# 53   SHADE / MATERIAL INCORRECT or CHANGED  MILLED IN A1(SUPPOSED TO BE B1)
# 60   SHADE / MATERIAL INCORRECT or CHANGED                           OPAQUE
# 109  SHADE / MATERIAL INCORRECT or CHANGED                 DR CHANGED SHADE
# 234  SHADE / MATERIAL INCORRECT or CHANGED                  OVEN NOT PURGED
#
#     LOCATION WHEN DAMAGED WAS NOTICED
# 52                             IN CAM
# 53                             IN CAM
# 60                           POST CAM
# 109                          POST CAM
# 234                          POST CAM

# %%
#Here I take the rows that were mistakenly entered by operators out of my data
#I do so by using a .index method to capture a range and assign to variable again to make it permanent
opaque_df=opaque_df.drop(opaque_df.index[0:2])
opaque_df = opaque_df.drop(opaque_df.index[1])

# %%
opaque_df
# Out:
#               Timestamp CAM OPERATOR BADGE#  \
# 60    3/5/2020 17:20:30              DROMIE
# 234   3/23/2020 8:43:09           TSCHAFFER
# 235   3/23/2020 8:43:49           TSCHAFFER
# 236  3/23/2020 10:28:56           TSCHAFFER
# 237  3/23/2020 10:30:34           TSCHAFFER
# 239  3/23/2020 10:42:43           TSCHAFFER
# 241  3/23/2020 11:05:12           TSCHAFFER
# 242  3/23/2020 11:05:54           TSCHAFFER
# 243  3/23/2020 11:19:36           TSCHAFFER
# 244  3/23/2020 11:20:31           TSCHAFFER
# 245  3/23/2020 11:35:43           TSCHAFFER
# 248  3/23/2020 13:33:20           TSCHAFFER
# 251  3/23/2020 15:06:49           TSCHAFFER
# 252  3/23/2020 15:47:59           TSCHAFFER
# 253  3/23/2020 15:48:52           TSCHAFFER
# 254  3/23/2020 15:49:26           TSCHAFFER
# 255  3/23/2020 15:50:24           TSCHAFFER
# 256  3/23/2020 15:51:07           TSCHAFFER
# 257  3/23/2020 15:52:32           TSCHAFFER
# 258  3/23/2020 16:43:56           TSCHAFFER
# 259  3/23/2020 16:44:30           TSCHAFFER
# 260  3/23/2020 16:45:04           TSCHAFFER
# 261  3/23/2020 17:01:09           TSCHAFFER
# 263   3/24/2020 5:53:45             ABEVELL
# 279   3/25/2020 8:59:40           TSCHAFFER
# 280   3/25/2020 9:24:30           TSCHAFFER
# 292   3/27/2020 8:02:07           TSCHAFFER
# 295   3/27/2020 8:47:29           TSCHAFFER
#
#                                      SCAN CASE NUMBER  \
# 60   ROLO101520008240ROLO101520008206ROLO101520008160
# 234                                  SARA101520010560
# 235                                  SARA101520010740
# 236                                  ROLO101520010659
# 237                                  ROLO101520010483
# 239                                  SARA101520010650
# 241                                  ROLO101520010579
# 242                                  ROLO101520010695
# 243                                  ROLO101520007955
# 244                                  ROLO101520010737
# 245                                  SARA101520010648
# 248                                  SARA101520010249
# 251                                  ROLO101520010765
# 252                                  ROLO101520010041
# 253                                  ROLO101520010795
# 254                                  ROLO101520010764
# 255                                  ROLO101520010774
# 256                                  ROLO101520010850
# 257                                  ROLO101520010013
# 258                                  SARA101520010766
# 259                                  SARA101520010784
# 260                                  SARA101520010827
# 261                                  ROLO101520010607
# 263                                  ROLO101520010707
# 279                                  SARA101520010888
# 280                                  SARA101520010890
# 292                                  ROLO101520005758
# 295                                  ROLO101520010886
#
#                            DEFECT CATEGORY DEFECT DESCRIPTION  \
# 60   SHADE / MATERIAL INCORRECT or CHANGED             OPAQUE
# 234  SHADE / MATERIAL INCORRECT or CHANGED    OVEN NOT PURGED
# 235  SHADE / MATERIAL INCORRECT or CHANGED    OVEN NOT PURGED
# 236  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 237  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 239  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 241  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 242  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 243  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 244  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 245  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 248  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 251  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 252  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 253  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 254  SHADE / MATERIAL INCORRECT or CHANGED          TSCHAFFER
# 255  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 256  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 257  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 258  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 259  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 260  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUR
# 261  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 263  SHADE / MATERIAL INCORRECT or CHANGED             OPAQUE
# 279  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 280  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 292  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
# 295  SHADE / MATERIAL INCORRECT or CHANGED         TOO OPAQUE
#
#     LOCATION WHEN DAMAGED WAS NOTICED
# 60                           POST CAM
# 234                          POST CAM
# 235                          POST CAM
# 236                          POST CAM
# 237                          POST CAM
# 239                          POST CAM
# 241                          POST CAM
# 242                          POST CAM
# 243                          POST CAM
# 244                          POST CAM
# 245                          POST CAM
# 248                          POST CAM
# 251                          POST CAM
# 252                          POST CAM
# 253                          POST CAM
# 254                          POST CAM
# 255                          POST CAM
# 256                          POST CAM
# 257                          POST CAM
# 258                          POST CAM
# 259                          POST CAM
# 260                          POST CAM
# 261                          POST CAM
# 263                          POST CAM
# 279                          POST CAM
# 280                          POST CAM
# 292                          POST CAM
# 295                          POST CAM

# %%
cam_df=pd.read_csv('NumpyCsvTraining1 - Sheet1.csv',sep=',')

# %%
cam_df.describe()
# Out:
#        Number of crowns / items
# count                 37.000000
# mean                   3.972973
# std                    2.242103
# min                    1.000000
# 25%                    2.000000
# 50%                    4.000000
# 75%                    5.000000
# max                   10.000000

# %%
cam_df.head()
# Out:
#             Timestamp SCAN OR ENTER OPERATOR NAME  \
# 0   3/20/2020 6:56:37                   TSCHAFFER
# 1  3/21/2020 11:50:54                      dlee
# 2   3/20/2020 9:42:18                   TSCHAFFER
# 3  3/23/2020 10:31:33                   TSCHAFFER
# 4  3/20/2020 16:48:30                   TSCHAFFER
#
#                                 SCAN CASE(S) BARCODE  \
# 0                   SARA101520006361SARA101520010560
# 1  ROLO101520010798ROLO101520010797ROLO1015200107...
# 2  SARA101520010605SARA101520010650SARA1015200107...
# 3                   ROLO101520010659ROLO101520010483
# 4                                   ROLO101520010607
#
#   CHOOSE RESTORATION TYPE(S)  \
# 0                   FCZ, PFZ
# 1                   FCZ, PFZ
# 2                        FCZ
# 3                        FCZ
# 4                        FCZ
#
#                            SCAN / ENTER PUCK BARCODE  \
# 0  SARA122843|1|EA|19281409|18995351|20071558510014|
# 1  ROLO121993|1|EA|19243082|19067594|20072311890027|
# 2  SARA122841|1|EA|19268323|18946939|20070279840004|
# 3  ROLO121785|1|EA|18903292|18903761|20049221820014|
# 4  ROLO122031|1|EA|19112410|19043887|20048339330005|
#
#    Number of crowns / items PLEASE CHOOSE SHADE PLEASE CHOOSE MILLING MACHINE
# 0                         4                  A2              5X400 VERSAMILL3
# 1                        10                  A3              5X200 VERSAMILL4
# 2                         8                  A2               5X400 VERSAMILL
# 3                         2                A3.5                    ROLAND 206
# 4                         1                  C4                    ROLAND 206

# %%
cam_df.plot(x='Timestamp', kind = 'bar')
